# %%
from io import StringIO
from pathlib import Path
import pandas as pd
from Bio import SeqIO
from Bio.Blast.Applications import NcbiblastnCommandline

# %%
def removal_overlap(records):
    results = []
    for _, group in records.groupby('Position in contig'):
        uniques = []
        for _, row in group.iterrows():
            if uniques:
                overlaps = set()
                for unique in uniques:
                    overlaps.add(len(set(range(row['qstart'], row['qend'])) & set(range(unique['qstart'], unique['qend']))))
                if max(overlaps) == 0:
                    uniques.append(row)
            else:
                uniques.append(row)
        results += uniques
    return pd.DataFrame(results)

# %%
query = '/media/Central_Lab_Storage/MinION/mNGS/20211006_CMUH/denovo/barcode10/contigs.fa'

# %%
database = '/media/GenomicResearch/Tools/CGE/resfinder_db'

align_results = []
for seqfile in Path(database).glob('*.fsa'):
    cline = NcbiblastnCommandline(
        query=query,
        subject=seqfile,
        outfmt='6 qseqid sseqid sstrand length qstart qend sstart send slen',
        perc_identity=90,
    )
    stdout_str, stderr_str = cline()
    align_result = pd.read_csv(StringIO(stdout_str), sep='\t', header=None, names=['qseqid', 'sseqid', 'sstrand', 'length', 'qstart', 'qend', 'sstart', 'send', 'slen'])
    align_result['cov'] = align_result['length']/align_result['slen']*100
    align_result = align_result[align_result['cov']>=60]
    align_result = removal_overlap(align_result)
    align_results.append(align_result)

# %%
df = pd.concat(align_results, ignore_index=True)

# %%
df['gene'] = df['sseqid'].str.split('_', 1).str[0]

# %%
df = df.drop_duplicates('gene')

# %%
phenotypes = pd.read_csv(Path(database, 'phenotypes.txt'), sep='\t', usecols=['Gene_accession no.', 'Phenotype'])

# %%
df.merge(phenotypes, left_on='sseqid', right_on='Gene_accession no.').drop(['sseqid', 'Gene_accession no.'], axis=1)
# Out:
#      qseqid sstrand  length   qstart     qend  sstart  send  slen         cov  \
# 0  contig_1    plus    1443   120668   122110       1  1440  1440  100.208333
# 1  contig_1    plus     771  1937629  1938399       1   771   771  100.000000
# 2  contig_1    plus    2009  1932178  1934186       1  2007  2007  100.099651
# 3  contig_1   minus     888   217899   218785     888     1   888  100.000000
# 4  contig_1    plus    1545   112828   114372       1  1545  1545  100.000000
# 5  contig_1    plus     430  2133156  2133585       1   429   429  100.233100
# 6  contig_1    plus     642   196772   197413       1   642   642  100.000000
# 7  contig_2   minus     735     2724     3458     735     1   735  100.000000
#
#                gene                                          Phenotype
# 0  aac(6')-aph(2'')  Gentamicin, Tobramycin, Netilmicin, Kanamycin,...
# 1              aadD                               Amikacin, Tobramycin
# 2              mecA  Amoxicillin, Amoxicillin+Clavulanic acid, Ampi...
# 3              blaZ  Amoxicillin, Ampicillin, Penicillin, Piperacillin
# 4              qacA  Benzylkonium Chloride, Ethidium Bromide, Chlor...
# 5              fosB                                         Fosfomycin
# 6              fusB                                       Fusidic acid
# 7            erm(C)  Erythromycin, Lincomycin, Clindamycin, Quinupr...

# %%
df = pd.read_csv('/media/Central_Lab_Storage/MinION/mNGS/20211028_ICU001/resfinder/barcode30/ResFinder_results_tab.txt', sep='\t')

# %%
df['qstart'], df['qend'] = df['Position in contig'].str.split('\.\.').str
df['qstart'], df['qend'] = df['qstart'].astype(int), df['qend'].astype(int)
# Out:
# /home/chen1i6c04/miniconda3/envs/notebook/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   """Entry point for launching an IPython kernel.

# %%
removal_overlap(df)
# Out:
#    Resistance gene  Identity Alignment Length/Gene Length    Coverage  \
# 18            sul2    100.00                      816/816  100.000000
# 4      aph(3'')-Ib    100.00                      804/804  100.000000
# 2        aph(6)-Id    100.00                      837/837  100.000000
# 3       aph(3')-Ia    100.00                      816/816  100.000000
# 22           dfrA7    100.00                      474/474  100.000000
# 27            qacE    100.00                      282/333   84.684685
# 17            sul1    100.00                      840/840  100.000000
# 20          tet(D)    100.00                    1185/1185  100.000000
# 5       blaSHV-187     99.88                      867/867  100.000000
# 19          tet(A)     99.75                    1200/1200  100.000000
# 9             fosA     99.29                      420/420  100.000000
# 16            sul1    100.00                      840/840  100.000000
# 26            qacE    100.00                      282/333   84.684685
# 12           qnrB6    100.00                      645/645  100.000000
# 8        blaOXA-48    100.00                      798/798  100.000000
# 15            sul1    100.00                      840/840  100.000000
# 25            qacE    100.00                      282/333   84.684685
# 0           aadA16     99.65                      846/846  100.000000
# 21          dfrA27    100.00                      474/474  100.000000
# 14           ARR-3    100.00                      453/453  100.000000
# 1    aac(6')-Ib-cr    100.00                      600/600  100.000000
# 10            OqxB     99.27                    3153/3153  100.000000
# 11            OqxA    100.00                    1176/1176  100.000000
# 6      blaCTX-M-15    100.00                      876/876  100.000000
# 7        blaTEM-1C    100.00                      861/861  100.000000
#
#    Position in reference           Contig Position in contig  \
# 18                1..816  contig_1_polish     109253..110068
# 4                 1..804  contig_1_polish     110129..110932
# 2                 1..837  contig_1_polish     110932..111768
# 3                 1..816  contig_1_polish     112684..113499
# 22                1..474  contig_1_polish     121273..121746
# 27                1..282  contig_1_polish     121976..122257
# 17                1..840  contig_1_polish     122317..123156
# 20               1..1185  contig_1_polish     126957..128141
# 5                 1..867  contig_7_polish   2195720..2196586
# 19               1..1200  contig_9_polish       25096..26295
# 9                 1..420  contig_7_polish   4075662..4076081
# 16                1..840  contig_9_polish       42965..43804
# 26                1..282  contig_9_polish       43864..44145
# 12                1..645  contig_9_polish       44376..45020
# 8                 1..798  contig_8_polish       46198..46995
# 15                1..840  contig_9_polish       48431..49270
# 25                1..282  contig_9_polish       49330..49611
# 0                 1..846  contig_9_polish       49728..50573
# 21                1..474  contig_9_polish       50754..51227
# 14                1..453  contig_9_polish       51360..51812
# 1                 1..600  contig_9_polish       51909..52508
# 10               1..3153  contig_7_polish     722873..726025
# 11               1..1176  contig_7_polish     726049..727224
# 6                 1..876  contig_4_polish       82922..83797
# 7                 1..861  contig_4_polish       87685..88545
#
#                                             Phenotype Accession no.   qstart  \
# 18                            Sulphonamide resistance      FN995456   109253
# 4   Aminoglycoside resistance Alternate name; aph(...      AF321551   110129
# 2   Aminoglycoside resistance Alternate name; aph(...        M28829   110932
# 3                           Aminoglycoside resistance        V00359   112684
# 22                            Trimethoprim resistance      AB161450   121273
# 27                            Disinfectant resistance        X68232   121976
# 17                            Sulphonamide resistance        U12338   122317
# 20                            Tetracycline resistance      AF467077   126957
# 5                              Beta-lactam resistance      LN515533  2195720
# 19                            Tetracycline resistance      AY196695    25096
# 9                               Fosfomycin resistance  ACWO01000079  4075662
# 16                            Sulphonamide resistance        U12338    42965
# 26                            Disinfectant resistance        X68232    43864
# 12                               Quinolone resistance      EF523819    44376
# 8                              Beta-lactam resistance      AY236073    46198
# 15                            Sulphonamide resistance        U12338    48431
# 25                            Disinfectant resistance        X68232    49330
# 0                           Aminoglycoside resistance      EU675686    49728
# 21                            Trimethoprim resistance      FJ459817    50754
# 14                              Rifampicin resistance      JF806499    51360
# 1       Fluoroquinolone and aminoglycoside resistance      DQ303918    51909
# 10                            Disinfectant resistance      EU370913   722873
# 11                            Disinfectant resistance      EU370913   726049
# 6        Beta-lactam resistance Alternate name; UOE-1      AY044436    82922
# 7    Beta-lactam resistance Alternate name; RblaTEM-1      FJ560503    87685
#
#        qend
# 18   110068
# 4    110932
# 2    111768
# 3    113499
# 22   121746
# 27   122257
# 17   123156
# 20   128141
# 5   2196586
# 19    26295
# 9   4076081
# 16    43804
# 26    44145
# 12    45020
# 8     46995
# 15    49270
# 25    49611
# 0     50573
# 21    51227
# 14    51812
# 1     52508
# 10   726025
# 11   727224
# 6     83797
# 7     88545
